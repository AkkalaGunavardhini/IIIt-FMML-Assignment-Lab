# %% [markdown]
# <a href="https://colab.research.google.com/github/AkkalaGunavardhini/IIIt-FMML-Assignment-Lab/blob/main/Mod8_Lab3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Bayesian Machine Learning: Lab 3 - Applying Bayes Classifiers

# %% [markdown]
# Lab by V Vijay Vignesh
#
# vijay.vignesh@research.iiit.ac.in

# %%
import os
import json
import re

import numpy as np
import pandas as pd

from matplotlib import pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as pg

import tensorflow as tf
import tensorflow_probability as tfp

# %%
# !wget https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
plt.style.use('ggplot')
# Out:
# --2024-05-23 10:12:34--  https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.111.133, 185.199.109.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 72422946 (69M) [text/plain]
# Saving to: ‘arxiv-paper-data.json’
#
# arxiv-paper-data.js 100%[===================>]  69.07M   120MB/s    in 0.6s
#
# 2024-05-23 10:12:34 (120 MB/s) - ‘arxiv-paper-data.json’ saved [72422946/72422946]

# %% [markdown]
# Let's make a few assumptions to come up with our first general model for classification:
# * The different features contribute equally to the result
# * The features are independent

# %% [markdown]
# ## Bayes Classifiers in Scikit Learn

# %% [markdown]
# ### Simple 1-D Classfication using Naive Bayes in Continuous Space

# %%
fig, ax = plt.subplots(figsize=(18, 8))
x1 = np.random.normal(1.0, 0.3, size=5000)
x2 = np.random.normal(0.0, 0.3, size=50000)
x = np.concatenate([x1, x2])
y = np.concatenate([np.zeros(len(x1)), np.ones(len(x2))])
sns.histplot(x1, color='blue', alpha=0.5, ax=ax)
sns.histplot(x2, color='red', alpha=0.5, ax=ax)
ax.fill_between(np.linspace(-1.0, 0.7, 100), 0, 1800,  color='r', alpha=0.1)
ax.fill_between(np.linspace(0.7, 2.0, 100), 0, 1800,  color='b', alpha=0.1)
ax.vlines(0.5, 0, 1750, color="k", linestyles="--", lw=3)
ax.vlines(0.7, 0, 1750, color="g", linestyles="--", lw=3)
ax.scatter(x1, [np.random.randint(2000, 3000) for _ in x1], color='b', s=1)
ax.scatter(x2, [np.random.randint(2000, 3000) for _ in x2], color='r', s=1)
ax.set_xlim(-1.0, 2.0)
ax.set_ylim(0, 3200)
plt.show()

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
x_reshaped = x.reshape(1, -1)
print(x_reshaped.shape)
# Out:
# (1, 55000)

# %% [markdown]
# ## Gaussian Bayes Predictor on Predicting Flowers

# %% [markdown]
# ### Predictors in Scikit Learn

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB

X, y = load_iris(return_X_y=True)
X = X[:, [2, 3]]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=0)
gnb = GaussianNB()
gnb.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
plt.figure(figsize=(20, 10))
color_scheme = ['red', 'green', 'blue']
plt.scatter(X_train[:, 0], X_train[:, 1], c=[color_scheme[idx] for idx in y_train])
plt.show()

# %% [markdown]
# ### Visualizing the Decision Surface

# %%
plt.figure(figsize=(20, 10))
X1_scan, X2_scan = np.meshgrid(np.linspace(0.5, 7.5, 250), np.linspace(0.0, 3.0, 250))
X_scan = np.stack([np.reshape(X1_scan, -1), np.reshape(X2_scan, -1)], axis=-1)
predictions = gnb.predict(X_scan)
color_map = ['r', 'g', 'b']
plt.scatter(x=X_test[:, 0], y=X_test[:, 1], c=[color_map[x] for x in y_test])
sns.kdeplot(x=X_scan[:, 0], y=X_scan[:, 1], hue=[color_map[x] for x in predictions], fill=False)
plt.show()

# %% [markdown]
# ## Bayes on Text - Classifying papers at Arxiv

# %% [markdown]
# ### Data Cleaning and Preprocessing

# %%
arxiv_df = pd.read_json(open("arxiv-paper-data.json", 'r'))
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: json.loads(x.replace("\'", "\"").replace("None", "\"None\""))[0]['term'].split('.')[0])
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: 'physics' if x in ['physics', 'quant-ph', 'astro-ph', 'hep-ex', 'hep-ph', 'hep-lat', 'hep-th', 'nucl-th'] else x)
arxiv_df = arxiv_df.drop(["day", "month", "link", "author"], axis=1)

# %%
SAMPLES_COMP = 3500 #@param {type: "slider", min: 1000, max: 4500}
SAMPLES_STAT = 2500 #@param {type: "slider", min: 1000, max: 4500}
WORD_COUNT_THRESHOLD = 1  #@param {type: "slider", min: 1, max: 500}
WORD_LENGTH_THRESHOLD = 8  #@param {type: "slider", min: 4, max: 20}

# %%
df = pd.concat([arxiv_df[arxiv_df['tag'] == 'cs'].sample(SAMPLES_COMP, replace=False),
                arxiv_df[arxiv_df['tag'] == 'stat'].sample(SAMPLES_STAT, replace=False)]).sample(frac=1)
df['keywords'] = df.apply(lambda x: [word.lower() for word in re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', x.summary + ' ' + x.title)).split()
                                     if len(word) > WORD_LENGTH_THRESHOLD and not re.search('(\d|\(|\))', word)], axis=1)
train_df, test_df = df.iloc[:int(len(df) * 0.8)], df.iloc[int(len(df) * 0.8):]

train_df
# Out:
#                  id                                            summary   tag  \
# 22766  1706.02326v2  In this paper, we propose a new volume-preserv...  stat
# 342    1702.04267v2  Machine learning and deep learning in particul...  stat
# 12191  1710.04234v2  Learning a regression function using censored ...  stat
# 24844   1412.2873v1  This paper deals with the multiple annotation ...    cs
# 453    1603.00423v1  Recursive neural networks (RNN) and their rece...    cs
# ...             ...                                                ...   ...
# 7619   1802.05187v1  Deep convolutional network has been the state-...  stat
# 6056   1606.05908v2  In just three years, Variational Autoencoders ...  stat
# 22522  1610.08035v4  We propose a parallelizable sparse inverse for...  stat
# 28380  1706.04256v1  Computational imaging methods that can exploit...    cs
# 2404   1604.07706v3  We provide two distributed confidence ball alg...    cs
#
#                                                    title  year  \
# 22766  Improving Variational Auto-Encoders using conv...  2017
# 342               On Detecting Adversarial Perturbations  2017
# 12191                      Maximum Margin Interval Trees  2017
# 24844  Cancer Detection with Multiple Radiologists vi...  2014
# 453    Quantifying the vanishing gradient and long di...  2016
# ...                                                  ...   ...
# 7619         On the Blindspots of Convolutional Networks  2018
# 6056                Tutorial on Variational Autoencoders  2016
# 22522  Parallelizable sparse inverse formulation Gaus...  2016
# 28380  Online Convolutional Dictionary Learning for M...  2017
# 2404   Distributed Clustering of Linear Bandits in Pe...  2016
#
#                                                 keywords
# 22766  [preserving, similarly, normalizing, autoregre...
# 342    [particular, tremendously, perceptual, vulnera...
# 12191  [regression, important, prediction, algorithms...
# 24844  [annotation, application, detection, assumptio...
# 453    [recursive, extension, recursive, representati...
# ...                                                  ...
# 7619   [convolutional, successes, demonstrate, convol...
# 6056   [variational, autoencoders, approaches, unsupe...
# 22522  [parallelizable, formulation, precision, formu...
# 28380  [computational, modalities, potential, capabil...
# 2404   [distributed, confidence, algorithms, communic...
#
# [4800 rows x 6 columns]

# %%
df['keywords']
# Out:
# 22766    [preserving, similarly, normalizing, autoregre...
# 342      [particular, tremendously, perceptual, vulnera...
# 12191    [regression, important, prediction, algorithms...
# 24844    [annotation, application, detection, assumptio...
# 453      [recursive, extension, recursive, representati...
#                                ...
# 21651    [dictionary, processing, typically, dictionary...
# 39280    [quantification, instrumental, evolution, dens...
# 13223    [representation, independent, formulation, kol...
# 22717    [discriminated, graphical, graphical, providin...
# 9614     [hierarchical, clustering, description, public...
# Name: keywords, Length: 6000, dtype: object

# %% [markdown]
# ### Learning Probability Distributions

# %%
from collections import defaultdict
dictionary = defaultdict(lambda: [0, 0])
for desc, tag in zip(df['keywords'], df['tag']):
    for word in set(desc):
        if tag == 'cs':
            dictionary[word][0] += 1
        else:
            dictionary[word][1] += 1

print("We have a dictionary of", len(dictionary), "words.")

words, counts_cs, counts_stat = [], [], []
for word, count in dictionary.items():
    if count[0] + count[1] > WORD_COUNT_THRESHOLD:
        words.append(word)
        counts_cs.append(count[0])
        counts_stat.append(count[1])
print("Out of those", len(words), f"have over {WORD_COUNT_THRESHOLD} occurances")

fig = pg.Figure([pg.Bar(x=words[:200], y=counts_cs[:200]),
                 pg.Bar(x=words[:200], y=counts_stat[:200])])
fig.update_layout(title_text=f'Some random words and the frequency plot of those with over {WORD_COUNT_THRESHOLD} occurances')
fig.show()
# Out:
# We have a dictionary of 8724 words.
# Out of those 4577 have over 1 occurances
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="9b3bc4de-022e-49e5-98f8-bc74f172e25a" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("9b3bc4de-022e-49e5-98f8-bc74f172e25a")) {                    Plotly.newPlot(                        "9b3bc4de-022e-49e5-98f8-bc74f172e25a",                        [{"x":["similarly","combination","preserving","autoregressive","improving","triangular","outperforms","variational","histopathology","combining","competitive","normalizing","experimental","introducing","specifically","addressing","perceptual","adversarial","orthogonal","imperceptible","procedure","empirically","vulnerable","surprisingly","tremendously","adversaries","subnetwork","adversary","generalize","classification","perturbations","particular","detectors","detecting","distinguishing","classifier","containing","computing","nonlinear","investigate","benchmark","prediction","discriminative","important","minimizing","objective","regression","algorithms","programming","algorithm","simultaneously","demonstrate","complexity","annotator","application","probabilities","radiologists","malignant","differing","detection","preferable","experiments","annotation","different","minimizes","regularization","constraining","diagnosis","divergence","information","assumption","probability","optimizing","complementary","sentiment","sentences","according","explicitly","gradients","nevertheless","embeddings","explanation","externally","structure","quantifying","recursively","dependency","recursive","hierarchical","vanishing","including","backpropagation","extension","indicative","representations","artificial","recurrent","instances","directions","introduce","presenting","corrupted","locations","direction","orientations","formulation","measurements","irregular","robustness","estimation","partially","formulated","sensitive","collections","estimating","characterization","comprised","collection","correspondences","formulations","demonstration","communication","likelihood","regulation","framework","statistical","represent","hypothesis","represents","evolution","exponential","properties","carefully","advertising","dramatically","distributed","typically","displayed","candidate","efficient","improvements","utilizing","comparing","parameter","forwardbackward","challenge","behaviors","interested","enhancing","historical","experience","computation","unacceptable","effectively","evaluations","significant","effectiveness","communicate","preference","implementing","introduces","indicates","granularity","explanations","generation","presentation","mathematical","mathematicians","knowledge","therefore","techniques","automated","presentations","resulting","solutions","quadratic","identical","selection","penalized","parameterization","estimates","equivalent","augmented","decompose","developed","shrinkage","characterize","autoencoder","unsupervised","definition","illustrate","deficiency","unlabelled","questions","crowdsourcing","unreasonable","crowdsourced","controller","responses","inferring"],"y":[17,142,45,8,111,2,274,47,2,104,95,4,385,56,169,25,31,93,23,1,130,55,12,34,1,5,2,11,52,519,19,291,39,84,12,147,55,125,54,145,212,250,97,355,58,163,112,613,105,847,132,566,238,5,224,57,5,3,8,372,6,600,66,744,18,81,11,53,24,681,70,175,58,43,51,75,90,74,31,28,67,26,2,332,6,12,43,22,99,12,243,22,74,3,236,132,149,100,40,347,15,24,38,61,5,75,39,14,99,206,55,36,53,17,61,23,6,97,15,19,10,57,63,4,544,143,100,59,40,65,38,213,39,4,18,119,104,5,46,407,123,36,73,130,1,157,37,22,17,20,40,146,3,121,62,253,214,18,29,27,89,19,14,14,139,8,63,2,343,149,376,111,3,168,145,28,16,168,8,10,72,46,37,12,208,2,47,19,154,50,65,6,7,55,10,2,7,24,32,22],"type":"bar"},{"x":["similarly","combination","preserving","autoregressive","improving","triangula ...

# %% [markdown]
# For each word, for both the subjects, we can apply Bayes rule.
#
# $$P\bigg(\frac{\text{subject}}{\text{word}}\bigg) = P\bigg(\frac{\text{word}}{\text{subject}}\bigg) \times \frac{P(\text{subject})}{P(\text{word})}$$

# %% [markdown]
# ### Computing the resultant probabilities

# %%
prior = np.array([train_df["tag"].value_counts()["cs"], train_df["tag"].value_counts()["stat"]]) / len(train_df)
evidence = np.array([counts_cs / train_df["tag"].value_counts()["cs"], counts_stat / train_df["tag"].value_counts()["stat"]]).T
likelihood = (np.array(counts_cs) + np.array(counts_stat)) / len(train_df)

prior.shape, likelihood.shape, evidence.shape
# Out:
# ((2,), (4577,), (4577, 2))

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(
        np.multiply(this_counts.reshape(-1, 1), evidence), likelihood.reshape(-1, 1))) + 0.001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.8016666666666666

# %% [markdown]
# ### Visualizing a few examples

# %%
def explain(example):
    from IPython.display import HTML
    title, desc, answer = example["title"], example["summary"], example["tag"]
    html = ""
    title = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', title)))
    desc = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', desc)))
    for text in [title, desc]:
        for word in text.split():
            idx = words_to_index[word.lower()]
            if idx == -1:
                html += f"<span style=''>{word}</span> "
            else:
                posterior = np.multiply(evidence[idx], prior)
                posterior /= np.sum(posterior)
                if posterior[0] > posterior[1] if answer == 'cs' else (posterior[0] <= posterior[1]):
                    color = max(0.3, posterior[0] - posterior[1])
                    html += f"<span style='background-color:rgba(0, 255, 0, {color});'>{word}</span> "
                else:
                    color = max(0.3, posterior[1] - posterior[0])
                    html += f"<span style='background-color:rgba(255, 0, 0, {color});'>{word}</span> "
        html += "<br/><br/>"
    return HTML(html)

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>Fuzzy</span> <span style=''>based</span> <span style='background-color:rgba(0, 255, 0, 0.9333333333333333);'>Navigation</span> <span style=''>and</span> <span style=''>Control</span> <span style=''>of</span> <span style=''>a</span> <span style=''>Non</span> <span style='background-color:rgba(0, 255, 0, 1.0);'>Holonomic</span> <span style=''>Mobile</span> <span style=''>Robot</span> <br/><br/><span style=''>In</span> <span style=''>recent</span> <span style=''>years</span> <span style=''>the</span> <span style=''>use</span> <span style=''>of</span> <span style=''>non</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>analytical</span> <span style=''>methods</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>computing</span> <span style=''>such</span> <span style=''>as</span> <span style=''>fuzzy</span> <span style=''>logic</span> <span style='background-color:rgba(0, 255, 0, 0.8400000000000001);'>evolutionary</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>computation</span> <span style=''>and</span> <span style=''>neural</span> <span style=''>networks</span> <span style=''>has</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>demonstrated</span> <span style=''>the</span> <span style=''>utility</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>potential</span> <span style=''>of</span> <span style=''>these</span> <span style='background-color:rgba(0, 255, 0, 0.4444444444444444);'>paradigms</span> <span style=''>for</span> <span style='background-color:rgba(0, 255, 0, 0.75);'>intelligent</span> <span style=''>control</span> <span style=''>of</span> <span style=''>mobile</span> <span style=''>robot</span> <span style='background-color:rgba(0, 255, 0, 0.9333333333333333);'>navigation</span> <span style=''>In</span> <span style=''>this</span> <span style=''>paper</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.3191489361702128);'>theoretical</span> <span style=''>model</span> <span style=''>of</span> <span style=''>a</span> <span style=''>fuzzy</span> <span style=''>based</span> <span style='background-color:rgba(0, 255, 0, 0.92);'>controller</span> <span style=''>for</span> <span style=''>an</span> <span style='background-color:rgba(0, 255, 0, 0.7974683544303798);'>autonomous</span> <span style=''>mobile</span> <span style=''>robot</span> <span style=''>is</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>developed</span> <span style=''>The</span> <span style=''>paper</span> <span style=''>begins</span> <span style=''>with</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>mathematical</span> <span style=''>model</span> <span style=''>of</span> <span style=''>the</span> <span style=''>robot</span> <span style=''>that</span> <span style=''>involves</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 1.0);'>kinematic</span> <span style=''>model</span> <span style=''>Then</span> <span style=''>the</span> <span style=''>fuzzy</span> <span style=''>logic</span> <span style='background-color:rgba(0, 255, 0, 0.92);'>controller</span> <span style=''>is</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>developed</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>discussed</span> <span style=''>in</span> <span style=''>detail</span> <span style=''>The</span> <span style=''>proposed</span> <span style=''>method</span> <span style=''>is</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>successfully</span> <span style=''>tested</span> <span style=''>in</span> <span style='background-color:rgba(255, 0, 0, 0.3540372670807454);'>simulations</span> <span style=''>and</span> <span style=''>it</span> <span style=''>compares</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.33749999999999997);'>effectiveness</span> <span style=''>of</span> <span style= ...

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>Student</span> <span style=''>t</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Processes</span> <span style=''>as</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Alternatives</span> <span style=''>to</span> <span style=''>Gaussian</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Processes</span> <br/><br/><span style=''>We</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>investigate</span> <span style=''>the</span> <span style=''>Student</span> <span style=''>t</span> <span style=''>process</span> <span style=''>as</span> <span style=''>an</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>alternative</span> <span style=''>to</span> <span style=''>the</span> <span style=''>Gaussian</span> <span style=''>process</span> <span style=''>as</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>nonparametric</span> <span style=''>prior</span> <span style=''>over</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>functions</span> <span style=''>We</span> <span style=''>derive</span> <span style=''>closed</span> <span style=''>form</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>expressions</span> <span style=''>for</span> <span style=''>the</span> <span style=''>marginal</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>likelihood</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>predictive</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>distribution</span> <span style=''>of</span> <span style=''>a</span> <span style=''>Student</span> <span style=''>t</span> <span style=''>process</span> <span style=''>by</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>integrating</span> <span style=''>away</span> <span style=''>an</span> <span style=''>inverse</span> <span style=''>Wishart</span> <span style=''>process</span> <span style=''>prior</span> <span style=''>over</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>covariance</span> <span style=''>kernel</span> <span style=''>of</span> <span style=''>a</span> <span style=''>Gaussian</span> <span style=''>process</span> <span style=''>model</span> <span style=''>We</span> <span style=''>show</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>surprising</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>equivalences</span> <span style=''>between</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>different</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>hierarchical</span> <span style=''>Gaussian</span> <span style=''>process</span> <span style=''>models</span> <span style=''>leading</span> <span style=''>to</span> <span style=''>Student</span> <span style=''>t</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>processes</span> <span style=''>and</span> <span style=''>derive</span> <span style=''>a</span> <span style=''>new</span> <span style=''>sampling</span> <span style=''>scheme</span> <span style=''>for</span> <span style=''>the</span> <span style=''>inverse</span> <span style=''>Wishart</span> <span style=''>process</span> <span style=''>which</span> <span style=''>helps</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>elucidate</span> <span style=''>these</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>equivalences</span> <span style=''>Overall</span> <span style=''>we</span> <span style=''>show</span> <span style=''>that</span> <span style=''>a</span> <span style=''>Student</span> <span style=''>t</span> <span style=''>process</span> <span style=''>can</span> <span style=''>retain</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>attractive</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>properties</span> <span style=''>of</span> <span style=''>a</span> <span style=''>Gaussian</span> <span style=''>process</span> <span style=''>a</span> <span styl ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>Strong</span> <span style='background-color:rgba(255, 0, 0, 0.5000000000000001);'>Faithfulness</span> <span style=''>and</span> <span style=''>Uniform</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Consistency</span> <span style=''>in</span> <span style=''>Causal</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Inference</span> <br/><br/><span style=''>A</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>fundamental</span> <span style=''>question</span> <span style=''>in</span> <span style=''>causal</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>inference</span> <span style=''>is</span> <span style=''>whether</span> <span style=''>it</span> <span style=''>is</span> <span style=''>possible</span> <span style=''>to</span> <span style=''>reliably</span> <span style=''>infer</span> <span style='background-color:rgba(0, 255, 0, 0.7692307692307693);'>manipulation</span> <span style=''>effects</span> <span style=''>from</span> <span style='background-color:rgba(255, 0, 0, 0.44444444444444453);'>observational</span> <span style=''>data</span> <span style=''>There</span> <span style=''>are</span> <span style=''>a</span> <span style=''>variety</span> <span style=''>of</span> <span style=''>senses</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.6576576576576578);'>asymptotic</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>reliability</span> <span style=''>in</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.36160714285714296);'>statistical</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>literature</span> <span style=''>among</span> <span style=''>which</span> <span style=''>the</span> <span style=''>most</span> <span style=''>commonly</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>discussed</span> <span style='background-color:rgba(255, 0, 0, 0.6);'>frequentist</span> <span style=''>notions</span> <span style=''>are</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>pointwise</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>consistency</span> <span style=''>and</span> <span style=''>uniform</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>consistency</span> <span style=''>Uniform</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>consistency</span> <span style=''>is</span> <span style=''>in</span> <span style=''>general</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>preferred</span> <span style=''>to</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>pointwise</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>consistency</span> <span style=''>because</span> <span style=''>the</span> <span style=''>former</span> <span style=''>allows</span> <span style=''>us</span> <span style=''>to</span> <span style=''>control</span> <span style=''>the</span> <span style=''>worst</span> <span style=''>case</span> <span style=''>error</span> <span style=''>bounds</span> <span style=''>with</span> <span style=''>a</span> <span style=''>finite</span> <span style=''>sample</span> <span style=''>size</span> <span style=''>In</span> <span style=''>the</span> <span style=''>sense</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>pointwise</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>consistency</span> <span style=''>several</span> <span style=''>reliable</span> <span style=''>causal</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>inference</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithms</span> <span style=''>have</span> <span style=''>been</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>established</span> <span style=''>under</span> <span style=''>the</span> <span style=''>Markov</span> <span style=''>and</span> <span style='background-color:rgba(255, 0, 0, 0.5000000000000001);'>Faithfulness</span> <span style='background-color:rgba(255 ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>Reducing</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Crowdsourcing</span> <span style=''>to</span> <span style=''>Graphon</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Estimation</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Statistically</span> <br/><br/><span style='background-color:rgba(0, 255, 0, 0.3);'>Inferring</span> <span style=''>the</span> <span style=''>correct</span> <span style=''>answers</span> <span style=''>to</span> <span style=''>binary</span> <span style=''>tasks</span> <span style=''>based</span> <span style=''>on</span> <span style=''>multiple</span> <span style=''>noisy</span> <span style=''>answers</span> <span style=''>in</span> <span style=''>an</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>unsupervised</span> <span style=''>manner</span> <span style=''>has</span> <span style=''>emerged</span> <span style=''>as</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>canonical</span> <span style=''>question</span> <span style=''>for</span> <span style=''>micro</span> <span style=''>task</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>crowdsourcing</span> <span style=''>or</span> <span style=''>more</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>generally</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>aggregating</span> <span style=''>opinions</span> <span style=''>In</span> <span style=''>graphon</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>estimation</span> <span style=''>one</span> <span style=''>is</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>interested</span> <span style=''>in</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>estimating</span> <span style=''>edge</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>intensities</span> <span style=''>or</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>probabilities</span> <span style=''>between</span> <span style=''>nodes</span> <span style=''>using</span> <span style=''>a</span> <span style=''>single</span> <span style=''>snapshot</span> <span style=''>of</span> <span style=''>a</span> <span style=''>graph</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>realization</span> <span style=''>In</span> <span style=''>the</span> <span style=''>recent</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>literature</span> <span style=''>there</span> <span style=''>has</span> <span style=''>been</span> <span style=''>exciting</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>development</span> <span style=''>within</span> <span style=''>both</span> <span style=''>of</span> <span style=''>these</span> <span style=''>topics</span> <span style=''>In</span> <span style=''>the</span> <span style=''>context</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>crowdsourcing</span> <span style=''>the</span> <span style=''>key</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>intellectual</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>challenge</span> <span style=''>is</span> <span style=''>to</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>understand</span> <span style=''>whether</span> <span style=''>a</span> <span style=''>given</span> <span style=''>task</span> <span style=''>can</span> <span style=''>be</span> <span style=''>more</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>accurately</span> <span style=''>denoised</span> <span style=''>by</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>aggregating</span> <span style=''>answers</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>collected</span> <span style=''>from</span> <span style=''>other</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>different</span> <span style=''>tasks</span> <span style=''>In</span> <span style=''>the</span> <span style=''>context</span> <span style=''> ...

# %% [markdown]
# ### Visualizing the Learnt Words

# %%
print("Some Computer Science words are:")
for word_cs in np.argsort(evidence[:, 0] - evidence[:, 1])[-10:]:
    print(f"\t{words[word_cs]} ({evidence[word_cs, 0]})")
print()
print("Some Statistics words are:")
for word_st in np.argsort(evidence[:, 1] - evidence[:, 0])[-10:]:
    print(f"\t{words[word_st]} ({evidence[word_st, 1]})")
# Out:
# Some Computer Science words are:
# 	representation (0.1344717182497332)
# 	knowledge (0.12202063322660975)
# 	experimental (0.13696193525435787)
# 	architecture (0.09142653859836357)
# 	information (0.24226254002134473)
# 	segmentation (0.08288865172536464)
# 	different (0.2646744930629669)
# 	detection (0.13233724653148346)
# 	convolutional (0.1383849163998577)
# 	recognition (0.13874066168623267)
#
# Some Statistics words are:
# 	algorithm (0.38461538461538464)
# 	stochastic (0.13524384112619406)
# 	variables (0.13725490196078433)
# 	theoretical (0.1558572146807441)
# 	estimation (0.17244846656611362)
# 	statistical (0.1533433886375063)
# 	distribution (0.18753142282554047)
# 	inference (0.19054801407742583)
# 	dimensional (0.1925590749120161)
# 	regression (0.17647058823529413)

# %% [markdown]
# ## Probability Smoothing
#
# Probability smoothing is a language modeling technique that assigns some non-zero probability to events that were unseen in the training data. This has the effect that the probability mass is divided over more events, hence the probability distribution becomes more smooth.

# %% [markdown]
# ### Realizing the Problem

# %%
posterior = np.multiply(np.divide(evidence, np.reshape(likelihood, (-1, 1))), np.reshape(prior, (1, -1)))

fig = pg.Figure([pg.Bar(x=words, y=evidence[:20, 0]),
                 pg.Bar(x=words, y=posterior[:20, 0])])
fig.update_layout(title_text='Evidence and Posterior for each word')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="f5648226-ede7-482d-8c61-29578a8c3224" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("f5648226-ede7-482d-8c61-29578a8c3224")) {                    Plotly.newPlot(                        "f5648226-ede7-482d-8c61-29578a8c3224",                        [{"x":["similarly","combination","preserving","autoregressive","improving","triangular","outperforms","variational","histopathology","combining","competitive","normalizing","experimental","introducing","specifically","addressing","perceptual","adversarial","orthogonal","imperceptible","procedure","empirically","vulnerable","surprisingly","tremendously","adversaries","subnetwork","adversary","generalize","classification","perturbations","particular","detectors","detecting","distinguishing","classifier","containing","computing","nonlinear","investigate","benchmark","prediction","discriminative","important","minimizing","objective","regression","algorithms","programming","algorithm","simultaneously","demonstrate","complexity","annotator","application","probabilities","radiologists","malignant","differing","detection","preferable","experiments","annotation","different","minimizes","regularization","constraining","diagnosis","divergence","information","assumption","probability","optimizing","complementary","sentiment","sentences","according","explicitly","gradients","nevertheless","embeddings","explanation","externally","structure","quantifying","recursively","dependency","recursive","hierarchical","vanishing","including","backpropagation","extension","indicative","representations","artificial","recurrent","instances","directions","introduce","presenting","corrupted","locations","direction","orientations","formulation","measurements","irregular","robustness","estimation","partially","formulated","sensitive","collections","estimating","characterization","comprised","collection","correspondences","formulations","demonstration","communication","likelihood","regulation","framework","statistical","represent","hypothesis","represents","evolution","exponential","properties","carefully","advertising","dramatically","distributed","typically","displayed","candidate","efficient","improvements","utilizing","comparing","parameter","forwardbackward","challenge","behaviors","interested","enhancing","historical","experience","computation","unacceptable","effectively","evaluations","significant","effectiveness","communicate","preference","implementing","introduces","indicates","granularity","explanations","generation","presentation","mathematical","mathematicians","knowledge","therefore","techniques","automated","presentations","resulting","solutions","quadratic","identical","selection","penalized","parameterization","estimates","equivalent","augmented","decompose","developed","shrinkage","characterize","autoencoder","unsupervised","definition","illustrate","deficiency","unlabelled","questions","crowdsourcing","unreasonable","crowdsourced","controller","responses","inferring","achieving","naturally","necessary","probabilistic","dynamically","eliminating","parameters","theoretic","mechanical","implement","graphical","strategies","visualization","aggregate","superiority","congestion","effective","transformed","coordination","resources","challenging","utilization","significantly","environment","complicated","simplified","contextual","involving","platforms","approaches","extensive","substantially","stochastic","efficiency","satisfaction","empirical","dimensional","reinforcement","variations","transportation","management","alleviate","deconvolution","evaluated","conditional","expressions","expression","convolved","currently","equations","breakthroughs","specialize","cyberphysical","discretized","param ...

# %%
print("Some words which never appear in Computer Science paper:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_cs) == 0)[0][:20]]))
print("Some words which never appear in Statistics papers:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_stat) == 0)[0][:20]]))
# Out:
# Some words which never appear in Computer Science paper:
# 	warranted
# 	correspondingly
# 	blockmodels
# 	concordance
# 	integrator
# 	hamiltonians
# 	blockwise
# 	extrapolating
# 	reciprocity
# 	inversions
# 	cancellation
# 	unmodified
# 	topography
# 	electroencephalography
# 	tempering
# 	blackwellized
# 	coalescent
# 	reformulates
# 	nonlinearly
# 	dendrogram
# Some words which never appear in Statistics papers:
# 	radiologists
# 	unacceptable
# 	granularity
# 	mathematicians
# 	presentations
# 	congestion
# 	specialize
# 	cyberphysical
# 	telephone
# 	scalarizing
# 	enumerating
# 	argumentation
# 	nonmonotonic
# 	satisfiability
# 	propositional
# 	axiomatizations
# 	hyperlink
# 	extraordinary
# 	instruction
# 	hyperlinks

# %% [markdown]
# Notice the fact that there are cases where the Evidence $P\big(\frac{\text{word}}{\text{subject}}\big) \rightarrow 0$. This is because there are occurances of the given word in the corpus (all the abstract of papers put together) of that subject.
#
# However, this is no way implies that if a word (eg. Employment) never occurs in our training corpus in a Computer Science paper, it will also never occur in a paper in the test set.
#
# Therefore, setting $P(\text{word} | \text{subject}) = 0$ is incorrect, since it will make the posterior $P(\text{subject} | \text{word}) = 0$, even if the corresponding count it 0, we need to come up with a smoother formulation of the Evidence variables.

# %% [markdown]
# ### Laplace Smoothing
#
#
#
# https://towardsdatascience.com/laplace-smoothing-in-na%C3%AFve-bayes-algorithm-9c237a8bdece

# %%
alpha = 0.1
counts_cs, counts_stat = np.array(counts_cs), np.array(counts_stat)
evidence_smooth = np.array([(counts_cs + alpha) / (train_df["tag"].value_counts()["cs"] + alpha * len(words)),
                            (counts_stat + alpha) / (train_df["tag"].value_counts()["stat"] + alpha * len(words))]).T
print(np.min(evidence_smooth))
sns.displot(evidence_smooth)
# Out:
# 3.059320219047328e-05

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(np.multiply(this_counts.reshape(-1, 1), evidence_smooth), likelihood.reshape(-1, 1))) + 0.0000001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.7533333333333333
